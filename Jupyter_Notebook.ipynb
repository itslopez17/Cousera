# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Jorge Lopez De Miguel**
#
# I would like to work in the banking enviroment as a data scientist.

# %% [markdown]
# *I am interested in data science because it is realy interesting to predict thing using current data*

# %% [markdown]
# ### In the next line there is some code that should print "My name is Jorge"

# %%
print("My name is Jorge")
# Out:
# My name is Jorge

# %% [markdown]
# | Tables        | Are           | Cool  |
# | ------------- |:-------------:| -----:|
# | nice     | try | 1 |
#
# 1. Hi
# 2. How are you?
# 3. I'm Jorge
#
# [Go to GOOGLE](https://www.google.com)
